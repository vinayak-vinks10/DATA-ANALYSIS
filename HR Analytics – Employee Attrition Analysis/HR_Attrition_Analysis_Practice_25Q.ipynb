# %% [markdown]
# # 👥 HR Analytics – Employee Attrition Analysis (Practice Notebook)
#
# This notebook contains **25 real-world HR analytics questions**.
# 👉 **Solve each question using Pandas in the empty code cell provided below it.**
# 👉 No solutions are given intentionally.
#
# ---

# %% [markdown]
# ## Dataset
# `hr_employee_attrition_500plus.csv`

# %% [markdown]
# ## A. Data Understanding & Cleaning

# %% [markdown]
# ### Q1. Find the total number of rows and columns in the dataset.

# %% [markdown]
# ### Q2. Identify numeric, categorical, and ordinal columns.

# %% [markdown]
# ### Q3. Check column-wise missing values.

# %% [markdown]
# ### Q4. Identify duplicate employee records.

# %% [markdown]
# ### Q5. Find unique values present in the Attrition column.

# %% [markdown]
# ## B. Employee Overview

# %% [markdown]
# ### Q6. Calculate the total number of employees.

# %% [markdown]
# ### Q7. Find the average age of employees.

# %% [markdown]
# ### Q8. Find the minimum and maximum age.

# %% [markdown]
# ### Q9. Analyze gender-wise employee distribution.

# %% [markdown]
# ### Q10. Find department-wise employee count.

# %% [markdown]
# ## C. Attrition Analysis

# %% [markdown]
# ### Q11. Calculate overall attrition count (Yes / No).

# %% [markdown]
# ### Q12. Calculate overall attrition rate (percentage).

# %% [markdown]
# ### Q13. Analyze department-wise attrition count.

# %% [markdown]
# ### Q14. Perform JobRole-wise attrition analysis.

# %% [markdown]
# ### Q15. Identify the department with the highest attrition.

# %% [markdown]
# ## D. Salary & Experience Analysis

# %% [markdown]
# ### Q16. Compare average monthly income for Attrition Yes vs No.

# %% [markdown]
# ### Q17. Compare average YearsAtCompany for Attrition Yes vs No.

# %% [markdown]
# ### Q18. Analyze attrition in low income group (MonthlyIncome < 30000).

# %% [markdown]
# ### Q19. Calculate attrition rate for employees with YearsSinceLastPromotion > 3.

# %% [markdown]
# ### Q20. Analyze relationship between experience and attrition.

# %% [markdown]
# ## E. Satisfaction & Work-Life Balance

# %% [markdown]
# ### Q21. Analyze JobSatisfaction distribution.

# %% [markdown]
# ### Q22. Calculate attrition rate for low JobSatisfaction (1–2).

# %% [markdown]
# ### Q23. Analyze relationship between WorkLifeBalance and Attrition.

# %% [markdown]
# ### Q24. Identify JobSatisfaction level with the lowest attrition.

# %% [markdown]
# ### Q25. Based on data, identify top 3 reasons for attrition.
